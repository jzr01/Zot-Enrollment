# %%
import pandas as pd
import re

# %%
df = pd.read_csv('class.csv',header = )

# %%
df
# Out:
#                                                    0     1    2      3   \
# 0   �Math � 120B � ��INTRO RINGS/FIELDS� � � (Prer...   NaN  NaN    NaN
# 1                                                Code  Type  Sec  Units
# 2                                               45040   Lec    A      4
# 3                                               45041   Dis   A1      0
# 4                                               45044   Lec    B      4
# 5                                               45045   Dis   B1      0
# 6   I&C Sci � 45C � ��PROGRAM IN C/C++� � � (Prere...   NaN  NaN    NaN
# 7                                                Code  Type  Sec  Units
# 8                                               35630   Lec    A      4
# 9   I&C Sci � 45J � ��PROGRAMMING IN JAVA� � � (Pr...   NaN  NaN    NaN
# 10                                               Code  Type  Sec  Units
# 11                                              35640   Lec    A      4
# ...

# %%
df.iloc[6,0]
# Out:
# 'I&C Sci � 45C � ��PROGRAM IN C/C++� � � (Prerequisites)'

# %%
df.iloc[2,5]
# Out:
# 'MWF � 10:00-10:50'

# %%
def get_class_name(s:str) -> str:
